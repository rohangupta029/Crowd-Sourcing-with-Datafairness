# %% [markdown]
# # Binarisation

# %%
import pandas as pd

# %%
df= pd.read_csv("compas-scores.csv")

# %%
df.head()
# Out:
#    id              name    first       last compas_screening_date   sex  \
# 0   1  miguel hernandez   miguel  hernandez             8/14/2013  Male
# 1   2      michael ryan  michael       ryan            12/31/2014  Male
# 2   3       kevon dixon    kevon      dixon             1/27/2013  Male
# 3   4          ed philo       ed      philo             4/14/2013  Male
# 4   5       marcu brown    marcu      brown             1/13/2013  Male
#
#          dob  age          age_cat              race  ...  vr_offense_date  \
# 0  4/18/1947   69  Greater than 45             Other  ...              NaN
# 1   2/6/1985   31          25 - 45         Caucasian  ...              NaN
# 2  1/22/1982   34          25 - 45  African-American  ...         7/5/2013
# 3  5/14/1991   24     Less than 25  African-American  ...              NaN
# 4  1/21/1993   23     Less than 25  African-American  ...              NaN
#
#                 vr_charge_desc  v_type_of_assessment  v_decile_score  \
# ...

# %%
from sklearn.preprocessing import Binarizer

# %%
bin= Binarizer(threshold=5)

# %%
col= df["decile_score.1"].values
col=col.reshape(-1,1)

# %%
col
# Out:
# array([[1],
#        [5],
#        [3],
#        ...,
#        [4],
#        [3],
#        [1]], dtype=int64)

# %%
bin.fit_transform(col)
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=int64)

# %%
df["decile_score.1"]=bin.fit_transform(col)

# %%
df
# Out:
#           id                    name     first           last  \
# 0          1        miguel hernandez    miguel      hernandez
# 1          2            michael ryan   michael           ryan
# 2          3             kevon dixon     kevon          dixon
# 3          4                ed philo        ed          philo
# 4          5             marcu brown     marcu          brown
# ...      ...                     ...       ...            ...
# 11752  11753        patrick hamilton   patrick       hamilton
# 11753  11754       raymond hernandez   raymond      hernandez
# 11754  11755  dieuseul pierre-gilles  dieuseul  pierre-gilles
# 11755  11756        scott lomagistro     scott     lomagistro
# 11756  11757                chin yan      chin            yan
#
#       compas_screening_date   sex        dob  age          age_cat  \
# 0                 8/14/2013  Male  4/18/1947   69  Greater than 45
# 1                12/31/2014  Male   2/6/1985   31          25 - 45
# ...

# %%
df=df.drop(["first"],axis=1)

# %%
df.head()
# Out:
#    id              name       last compas_screening_date   sex        dob  \
# 0   1  miguel hernandez  hernandez             8/14/2013  Male  4/18/1947
# 1   2      michael ryan       ryan            12/31/2014  Male   2/6/1985
# 2   3       kevon dixon      dixon             1/27/2013  Male  1/22/1982
# 3   4          ed philo      philo             4/14/2013  Male  5/14/1991
# 4   5       marcu brown      brown             1/13/2013  Male  1/21/1993
#
#    age          age_cat              race  juv_fel_count  ...  \
# 0   69  Greater than 45             Other              0  ...
# 1   31          25 - 45         Caucasian              0  ...
# 2   34          25 - 45  African-American              0  ...
# 3   24     Less than 25  African-American              0  ...
# 4   23     Less than 25  African-American              0  ...
#
#    vr_offense_date               vr_charge_desc  v_type_of_assessment  \
# 0              NaN                          NaN      Risk of Violence
# ...

# %%
df=df.drop(["last"],axis=1)

# %%
df.head()
# Out:
#    id              name compas_screening_date   sex        dob  age  \
# 0   1  miguel hernandez             8/14/2013  Male  4/18/1947   69
# 1   2      michael ryan            12/31/2014  Male   2/6/1985   31
# 2   3       kevon dixon             1/27/2013  Male  1/22/1982   34
# 3   4          ed philo             4/14/2013  Male  5/14/1991   24
# 4   5       marcu brown             1/13/2013  Male  1/21/1993   23
#
#            age_cat              race  juv_fel_count  decile_score  ...  \
# 0  Greater than 45             Other              0             1  ...
# 1          25 - 45         Caucasian              0             5  ...
# 2          25 - 45  African-American              0             3  ...
# 3     Less than 25  African-American              0             4  ...
# 4     Less than 25  African-American              0             8  ...
#
#    vr_offense_date               vr_charge_desc  v_type_of_assessment  \
# ...

# %%
df=df.drop(["compas_screening_date"],axis=1)

# %%
df.head(50)
# Out:
#     id                 name     sex         dob  age          age_cat  \
# 0    1     miguel hernandez    Male   4/18/1947   69  Greater than 45
# 1    2         michael ryan    Male    2/6/1985   31          25 - 45
# 2    3          kevon dixon    Male   1/22/1982   34          25 - 45
# 3    4             ed philo    Male   5/14/1991   24     Less than 25
# 4    5          marcu brown    Male   1/21/1993   23     Less than 25
# 5    6   bouthy pierrelouis    Male   1/22/1973   43          25 - 45
# 6    7         marsha miles    Male   8/22/1971   44          25 - 45
# 7    8        edward riddle    Male   7/23/1974   41          25 - 45
# 8    9       steven stewart    Male   2/25/1973   43          25 - 45
# 9   10     elizabeth thieme  Female    6/3/1976   39          25 - 45
# 10  11    darrell blackburn    Male  11/16/1995   20     Less than 25
# 11  12           jamie good  Female   4/23/1989   26          25 - 45
# ...

# %%
df.drop(df.loc[:, 'juv_fel_count':'vr_charge_desc'].columns, axis = 1)
# Out:
#           id                    name   sex        dob  age          age_cat  \
# 0          1        miguel hernandez  Male  4/18/1947   69  Greater than 45
# 1          2            michael ryan  Male   2/6/1985   31          25 - 45
# 2          3             kevon dixon  Male  1/22/1982   34          25 - 45
# 3          4                ed philo  Male  5/14/1991   24     Less than 25
# 4          5             marcu brown  Male  1/21/1993   23     Less than 25
# ...      ...                     ...   ...        ...  ...              ...
# 11752  11753        patrick hamilton  Male   5/2/1968   47  Greater than 45
# 11753  11754       raymond hernandez  Male  6/24/1993   22     Less than 25
# 11754  11755  dieuseul pierre-gilles  Male  1/24/1981   35          25 - 45
# 11755  11756        scott lomagistro  Male  12/4/1986   29          25 - 45
# 11756  11757                chin yan  Male  2/19/1982   34          25 - 45
#
# ...

# %%
df=df.drop(["screening_date"],axis=1)

# %%
df.head()
# Out:
#    id              name   sex        dob  age          age_cat  \
# 0   1  miguel hernandez  Male  4/18/1947   69  Greater than 45
# 1   2      michael ryan  Male   2/6/1985   31          25 - 45
# 2   3       kevon dixon  Male  1/22/1982   34          25 - 45
# 3   4          ed philo  Male  5/14/1991   24     Less than 25
# 4   5       marcu brown  Male  1/21/1993   23     Less than 25
#
#                race  juv_fel_count  decile_score  juv_misd_count  ...  \
# 0             Other              0             1               0  ...
# 1         Caucasian              0             5               0  ...
# 2  African-American              0             3               0  ...
# 3  African-American              0             4               0  ...
# 4  African-American              0             8               1  ...
#
#    vr_charge_degree  vr_offense_date               vr_charge_desc  \
# 0               NaN              NaN                          NaN
# ...

# %%
df.drop(df.loc[:, 'juv_fel_count':'vr_charge_desc'].columns, axis = 1)
# Out:
#           id                    name   sex        dob  age          age_cat  \
# 0          1        miguel hernandez  Male  4/18/1947   69  Greater than 45
# 1          2            michael ryan  Male   2/6/1985   31          25 - 45
# 2          3             kevon dixon  Male  1/22/1982   34          25 - 45
# 3          4                ed philo  Male  5/14/1991   24     Less than 25
# 4          5             marcu brown  Male  1/21/1993   23     Less than 25
# ...      ...                     ...   ...        ...  ...              ...
# 11752  11753        patrick hamilton  Male   5/2/1968   47  Greater than 45
# 11753  11754       raymond hernandez  Male  6/24/1993   22     Less than 25
# 11754  11755  dieuseul pierre-gilles  Male  1/24/1981   35          25 - 45
# 11755  11756        scott lomagistro  Male  12/4/1986   29          25 - 45
# 11756  11757                chin yan  Male  2/19/1982   34          25 - 45
#
# ...

# %%
df=df.drop(["v_screening_date"],axis=1)

# %%
df.head()
# Out:
#    id              name   sex        dob  age          age_cat  \
# 0   1  miguel hernandez  Male  4/18/1947   69  Greater than 45
# 1   2      michael ryan  Male   2/6/1985   31          25 - 45
# 2   3       kevon dixon  Male  1/22/1982   34          25 - 45
# 3   4          ed philo  Male  5/14/1991   24     Less than 25
# 4   5       marcu brown  Male  1/21/1993   23     Less than 25
#
#                race  juv_fel_count  decile_score  juv_misd_count  ...  \
# 0             Other              0             1               0  ...
# 1         Caucasian              0             5               0  ...
# 2  African-American              0             3               0  ...
# 3  African-American              0             4               0  ...
# 4  African-American              0             8               1  ...
#
#    vr_case_number  vr_charge_degree  vr_offense_date  \
# 0             NaN               NaN              NaN
# 1             NaN               NaN              NaN
# ...

# %%
df.head()
# Out:
#    id              name   sex        dob  age          age_cat  \
# 0   1  miguel hernandez  Male  4/18/1947   69  Greater than 45
# 1   2      michael ryan  Male   2/6/1985   31          25 - 45
# 2   3       kevon dixon  Male  1/22/1982   34          25 - 45
# 3   4          ed philo  Male  5/14/1991   24     Less than 25
# 4   5       marcu brown  Male  1/21/1993   23     Less than 25
#
#                race  juv_fel_count  decile_score  juv_misd_count  ...  \
# 0             Other              0             1               0  ...
# 1         Caucasian              0             5               0  ...
# 2  African-American              0             3               0  ...
# 3  African-American              0             4               0  ...
# 4  African-American              0             8               1  ...
#
#    vr_case_number  vr_charge_degree  vr_offense_date  \
# 0             NaN               NaN              NaN
# 1             NaN               NaN              NaN
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'sex', 'dob', 'age', 'age_cat', 'race', 'juv_fel_count',
#        'decile_score', 'juv_misd_count', 'juv_other_count', 'priors_count',
#        'days_b_screening_arrest', 'c_jail_in', 'c_jail_out', 'c_case_number',
#        'c_offense_date', 'c_arrest_date', 'c_days_from_compas',
#        'c_charge_degree', 'c_charge_desc', 'is_recid', 'num_r_cases',
#        'r_case_number', 'r_charge_degree', 'r_days_from_arrest',
#        'r_offense_date', 'r_charge_desc', 'r_jail_in', 'r_jail_out',
#        'is_violent_recid', 'num_vr_cases', 'vr_case_number',
#        'vr_charge_degree', 'vr_offense_date', 'vr_charge_desc',
#        'v_type_of_assessment', 'v_decile_score', 'v_score_text',
#        'type_of_assessment', 'decile_score.1', 'score_text'],
#       dtype='object')

# %%
df=df.drop(df.loc[:, 'juv_fel_count':'vr_charge_desc'].columns, axis = 1)

# %%
df.head()
# Out:
#    id              name   sex        dob  age          age_cat  \
# 0   1  miguel hernandez  Male  4/18/1947   69  Greater than 45
# 1   2      michael ryan  Male   2/6/1985   31          25 - 45
# 2   3       kevon dixon  Male  1/22/1982   34          25 - 45
# 3   4          ed philo  Male  5/14/1991   24     Less than 25
# 4   5       marcu brown  Male  1/21/1993   23     Less than 25
#
#                race v_type_of_assessment  v_decile_score v_score_text  \
# 0             Other     Risk of Violence               1          Low
# 1         Caucasian     Risk of Violence               2          Low
# 2  African-American     Risk of Violence               1          Low
# 3  African-American     Risk of Violence               3          Low
# 4  African-American     Risk of Violence               6       Medium
#
#    type_of_assessment  decile_score.1 score_text
# 0  Risk of Recidivism               0        Low
# 1  Risk of Recidivism               0     Medium
# ...

# %%
df.to_csv("final_Compas_Dataset.csv",index=False)

# %%
import pandas as pd
df= pd.read_csv("final_Compas_Dataset.csv")

# %%
df.head()
# Out:
#    id              name   sex        dob  age          age_cat  \
# 0   1  miguel hernandez  Male  4/18/1947   69  Greater than 45
# 1   2      michael ryan  Male   2/6/1985   31          25 - 45
# 2   3       kevon dixon  Male  1/22/1982   34          25 - 45
# 3   4          ed philo  Male  5/14/1991   24     Less than 25
# 4   5       marcu brown  Male  1/21/1993   23     Less than 25
#
#                race v_type_of_assessment  v_decile_score v_score_text  \
# 0             Other     Risk of Violence               1          Low
# 1         Caucasian     Risk of Violence               2          Low
# 2  African-American     Risk of Violence               1          Low
# 3  African-American     Risk of Violence               3          Low
# 4  African-American     Risk of Violence               6       Medium
#
#    type_of_assessment  decile_score score_text  Binary_Decile_Score
# 0  Risk of Recidivism             1        Low                    0
# ...

# %%
from sklearn.preprocessing import Binarizer
bin= Binarizer(threshold=5)
Binary_v_decile_score= df["v_decile_score"].values
Binary_v_decile_score=Binary_v_decile_score.reshape(-1,1)

# %%
Binary_v_decile_score
# Out:
# array([[1],
#        [2],
#        [1],
#        ...,
#        [3],
#        [2],
#        [1]], dtype=int64)

# %%
bin.fit_transform(Binary_v_decile_score)
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=int64)

# %%
df["v_decile_score"]=bin.fit_transform(Binary_v_decile_score)

# %%
df.head()
# Out:
#    id              name   sex        dob  age          age_cat  \
# 0   1  miguel hernandez  Male  4/18/1947   69  Greater than 45
# 1   2      michael ryan  Male   2/6/1985   31          25 - 45
# 2   3       kevon dixon  Male  1/22/1982   34          25 - 45
# 3   4          ed philo  Male  5/14/1991   24     Less than 25
# 4   5       marcu brown  Male  1/21/1993   23     Less than 25
#
#                race v_type_of_assessment  v_decile_score v_score_text  \
# 0             Other     Risk of Violence               0          Low
# 1         Caucasian     Risk of Violence               0          Low
# 2  African-American     Risk of Violence               0          Low
# 3  African-American     Risk of Violence               0          Low
# 4  African-American     Risk of Violence               1       Medium
#
#    type_of_assessment  decile_score score_text  Binary_Decile_Score
# 0  Risk of Recidivism             1        Low                    0
# ...

# %%
df.to_csv("FinalDataset.csv",index=False)

# %%
import pandas as pd

# %%
df= pd.read_csv("FinalDataset.csv")

# %%
df.head()
# Out:
#    id              name   sex        dob  age          age_cat  \
# 0   1  miguel hernandez  Male  4/18/1947   69  Greater than 45
# 1   2      michael ryan  Male   2/6/1985   31          25 - 45
# 2   3       kevon dixon  Male  1/22/1982   34          25 - 45
# 3   4          ed philo  Male  5/14/1991   24     Less than 25
# 4   5       marcu brown  Male  1/21/1993   23     Less than 25
#
#                race v_type_of_assessment  v_decile_score v_score_text  \
# 0  African-American     Risk of Violence               1          Low
# 1         Caucasian     Risk of Violence               2          Low
# 2  African-American     Risk of Violence               1          Low
# 3  African-American     Risk of Violence               3          Low
# 4  African-American     Risk of Violence               6       Medium
#
#    type_of_assessment  decile_score score_text  Binary_DScore  Binary_vdscore
# 0  Risk of Recidivism             1        Low              0               0
# ...

# %%
df["Code"]= pd.factorize(df.race)[0]

# %%
df.head(50)
# Out:
#     id                 name     sex         dob  age          age_cat  \
# 0    1     miguel hernandez    Male   4/18/1947   69  Greater than 45
# 1    2         michael ryan    Male    2/6/1985   31          25 - 45
# 2    3          kevon dixon    Male   1/22/1982   34          25 - 45
# 3    4             ed philo    Male   5/14/1991   24     Less than 25
# 4    5          marcu brown    Male   1/21/1993   23     Less than 25
# 5    6   bouthy pierrelouis    Male   1/22/1973   43          25 - 45
# 6    7         marsha miles    Male   8/22/1971   44          25 - 45
# 7    8        edward riddle    Male   7/23/1974   41          25 - 45
# 8    9       steven stewart    Male   2/25/1973   43          25 - 45
# 9   10     elizabeth thieme  Female    6/3/1976   39          25 - 45
# 10  11    darrell blackburn    Male  11/16/1995   20     Less than 25
# 11  12           jamie good  Female   4/23/1989   26          25 - 45
# ...

# %%
df.to_csv("finalDataset.csv",index=False)

# %%
from sklearn.preprocessing import Binarizer

# %%
bin= Binarizer(threshold=0)

# %%
col= df["Code"].values
col=col.reshape(-1,1)

# %%
col
# Out:
# array([[0],
#        [1],
#        [0],
#        ...,
#        [2],
#        [1],
#        [4]], dtype=int64)

# %%
bin.fit_transform(col)
# Out:
# array([[0],
#        [1],
#        [0],
#        ...,
#        [1],
#        [1],
#        [1]], dtype=int64)

# %%
df.head(50)
# Out:
#     id                 name     sex         dob  age          age_cat  \
# 0    1     miguel hernandez    Male   4/18/1947   69  Greater than 45
# 1    2         michael ryan    Male    2/6/1985   31          25 - 45
# 2    3          kevon dixon    Male   1/22/1982   34          25 - 45
# 3    4             ed philo    Male   5/14/1991   24     Less than 25
# 4    5          marcu brown    Male   1/21/1993   23     Less than 25
# 5    6   bouthy pierrelouis    Male   1/22/1973   43          25 - 45
# 6    7         marsha miles    Male   8/22/1971   44          25 - 45
# 7    8        edward riddle    Male   7/23/1974   41          25 - 45
# 8    9       steven stewart    Male   2/25/1973   43          25 - 45
# 9   10     elizabeth thieme  Female    6/3/1976   39          25 - 45
# 10  11    darrell blackburn    Male  11/16/1995   20     Less than 25
# 11  12           jamie good  Female   4/23/1989   26          25 - 45
# ...

# %%
df["decile_score.1"]=bin.fit_transform(col)

# %%
df.head(50)
# Out:
#     id                 name     sex         dob  age          age_cat  \
# 0    1     miguel hernandez    Male   4/18/1947   69  Greater than 45
# 1    2         michael ryan    Male    2/6/1985   31          25 - 45
# 2    3          kevon dixon    Male   1/22/1982   34          25 - 45
# 3    4             ed philo    Male   5/14/1991   24     Less than 25
# 4    5          marcu brown    Male   1/21/1993   23     Less than 25
# 5    6   bouthy pierrelouis    Male   1/22/1973   43          25 - 45
# 6    7         marsha miles    Male   8/22/1971   44          25 - 45
# 7    8        edward riddle    Male   7/23/1974   41          25 - 45
# 8    9       steven stewart    Male   2/25/1973   43          25 - 45
# 9   10     elizabeth thieme  Female    6/3/1976   39          25 - 45
# 10  11    darrell blackburn    Male  11/16/1995   20     Less than 25
# 11  12           jamie good  Female   4/23/1989   26          25 - 45
# ...

# %%
df.to_csv("finalDataset.csv",index=False)

# %%
df.head(10)
# Out:
#    id                name     sex        dob  age          age_cat  \
# 0   1    miguel hernandez    Male  4/18/1947   69  Greater than 45
# 1   2        michael ryan    Male   2/6/1985   31          25 - 45
# 2   3         kevon dixon    Male  1/22/1982   34          25 - 45
# 3   4            ed philo    Male  5/14/1991   24     Less than 25
# 4   5         marcu brown    Male  1/21/1993   23     Less than 25
# 5   6  bouthy pierrelouis    Male  1/22/1973   43          25 - 45
# 6   7        marsha miles    Male  8/22/1971   44          25 - 45
# 7   8       edward riddle    Male  7/23/1974   41          25 - 45
# 8   9      steven stewart    Male  2/25/1973   43          25 - 45
# 9  10    elizabeth thieme  Female   6/3/1976   39          25 - 45
#
#                race v_type_of_assessment  v_decile_score v_score_text  \
# 0  African-American     Risk of Violence               1          Low
# 1         Caucasian     Risk of Violence               2          Low
# ...

# %%
df["Sex_Code"]= pd.factorize(df.sex)[0]

# %%
df.head(50)
# Out:
#     id                 name     sex         dob  age          age_cat  \
# 0    1     miguel hernandez    Male   4/18/1947   69  Greater than 45
# 1    2         michael ryan    Male    2/6/1985   31          25 - 45
# 2    3          kevon dixon    Male   1/22/1982   34          25 - 45
# 3    4             ed philo    Male   5/14/1991   24     Less than 25
# 4    5          marcu brown    Male   1/21/1993   23     Less than 25
# 5    6   bouthy pierrelouis    Male   1/22/1973   43          25 - 45
# 6    7         marsha miles    Male   8/22/1971   44          25 - 45
# 7    8        edward riddle    Male   7/23/1974   41          25 - 45
# 8    9       steven stewart    Male   2/25/1973   43          25 - 45
# 9   10     elizabeth thieme  Female    6/3/1976   39          25 - 45
# 10  11    darrell blackburn    Male  11/16/1995   20     Less than 25
# 11  12           jamie good  Female   4/23/1989   26          25 - 45
# ...

# %%
df=df.drop(['Code'], axis = 1)

# %%
df.head(50)
# Out:
#     id                 name     sex         dob  age          age_cat  \
# 0    1     miguel hernandez    Male   4/18/1947   69  Greater than 45
# 1    2         michael ryan    Male    2/6/1985   31          25 - 45
# 2    3          kevon dixon    Male   1/22/1982   34          25 - 45
# 3    4             ed philo    Male   5/14/1991   24     Less than 25
# 4    5          marcu brown    Male   1/21/1993   23     Less than 25
# 5    6   bouthy pierrelouis    Male   1/22/1973   43          25 - 45
# 6    7         marsha miles    Male   8/22/1971   44          25 - 45
# 7    8        edward riddle    Male   7/23/1974   41          25 - 45
# 8    9       steven stewart    Male   2/25/1973   43          25 - 45
# 9   10     elizabeth thieme  Female    6/3/1976   39          25 - 45
# 10  11    darrell blackburn    Male  11/16/1995   20     Less than 25
# 11  12           jamie good  Female   4/23/1989   26          25 - 45
# ...

# %%
df.to_csv("finalDataset.csv",index=False)
